# %%
import pandas as pd
import numpy as np

pd.__version__
# Out:
# '1.4.2'

# %%
path = (r'C:\data_sets\vehicles.csv')
autos = pd.read_csv(path)
# Out:
# C:\Users\c_bal\AppData\Local\Temp\ipykernel_15144\622592954.py:2: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   autos = pd.read_csv(path)

# %%
cols = ['city08', 'comb08','highway08','displ','drive','eng_dscr','fuelCost08',
       'make','model','trany','range','createdOn','year']

autos[cols]
# Out:
#        city08  comb08  highway08  displ                       drive  \
# 0          19      21         25    2.0            Rear-Wheel Drive
# 1           9      11         14    4.9            Rear-Wheel Drive
# 2          23      27         33    2.2           Front-Wheel Drive
# 3          10      11         12    5.2            Rear-Wheel Drive
# 4          17      19         23    2.2  4-Wheel or All-Wheel Drive
# ...       ...     ...        ...    ...                         ...
# 44981      19      22         26    2.2           Front-Wheel Drive
# 44982      20      23         28    2.2           Front-Wheel Drive
# 44983      18      21         24    2.2  4-Wheel or All-Wheel Drive
# 44984      18      21         24    2.2  4-Wheel or All-Wheel Drive
# 44985      16      18         21    2.2  4-Wheel or All-Wheel Drive
#
#          eng_dscr  fuelCost08        make                model  \
# 0           (FFS)        3600  Alfa Romeo   Spider Veloce 2000
# ...

# %%
autos[cols].memory_usage(deep=True)

# %%
autos[cols].drive
# Out:
# 0                  Rear-Wheel Drive
# 1                  Rear-Wheel Drive
# 2                 Front-Wheel Drive
# 3                  Rear-Wheel Drive
# 4        4-Wheel or All-Wheel Drive
#                     ...
# 44981             Front-Wheel Drive
# 44982             Front-Wheel Drive
# 44983    4-Wheel or All-Wheel Drive
# 44984    4-Wheel or All-Wheel Drive
# 44985    4-Wheel or All-Wheel Drive
# Name: drive, Length: 44986, dtype: object

# %%
def func(element, to=[]):
    to.append(element)
    return to

print(func(12))
print(func(42))
# Out:
# [12]
# [12, 42]
