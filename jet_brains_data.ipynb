# %%
import pandas as pd
import numpy as np

# %%
url = 'https://github.com/mattharrison/datasets/raw/master/data/2020-jetbrains-python-survey.csv'

jb = pd.read_csv(url)
jb.head(15)
# Out:
# C:\Users\c_bal\AppData\Local\Temp\ipykernel_14392\3589676322.py:3: DtypeWarning: Columns (152) have mixed types. Specify dtype option on import or set low_memory=False.
#   jb = pd.read_csv(url)
#                               is.python.main other.lang.None other.lang.Java  \
# 0                                        Yes             NaN             NaN
# 1                                        Yes             NaN            Java
# 2                                        Yes             NaN             NaN
# 3                                        Yes             NaN             NaN
# 4                                        Yes             NaN            Java
# 5   No, I use Python as a secondary language             NaN             NaN
# 6                                        NaN             NaN             NaN
# 7   No, I use Python as a secondary language             NaN             NaN
# 8                                        Yes             NaN            Java
# ...

# %%
unique_cols = [] # gathering the columns into a list
for cols in jb.columns:
    if '.'  in cols:
        unique_cols.append(cols)
    if cols == 'age':
        unique_cols.append(cols)

(jb[unique_cols]
 .rename(columns=lambda c: c.replace('.', '_'))
 #are_you_datascientist= lambda df_: df_.are_you_datascientist
)
# Out:
#       is_python_main other_lang_None other_lang_Java other_lang_JavaScript  \
# 0                Yes             NaN             NaN                   NaN
# 1                Yes             NaN            Java            JavaScript
# 2                Yes             NaN             NaN                   NaN
# 3                Yes             NaN             NaN            JavaScript
# 4                Yes             NaN            Java            JavaScript
# ...              ...             ...             ...                   ...
# 54457            Yes             NaN             NaN                   NaN
# 54458            Yes             NaN             NaN            JavaScript
# 54459            Yes             NaN             NaN            JavaScript
# 54460            Yes             NaN             NaN            JavaScript
# 54461            Yes             NaN             NaN            JavaScript
#
# ...

# %%
(jb[unique_cols]
 .rename(columns=lambda c: c.replace('.', '_')) # renaming the columns that have a '.' in them and replacing it with '_' -- returns a new dataframe
 .assign(age=jb.age.str.slice(0,2).astype('float').astype('Int64'),
         are_you_datascientist = lambda df: df.are_you_datascientist
         .replace({'Yes': True, 'No': False, np.nan: False}),
         is_python_main = lambda df: df.is_python_main
         .astype('category')
        # company_size = lambda df: df.company_size
         #.replace({


        )
         
         #.value_counts(dropna=False)


)

#jb2.other_lang_None.fillna(value=False)
# Out:
# CategoricalDtype(categories=['No, I don’t use Python for my current projects',
#                   'No, I use Python as a secondary language', 'Yes'],
# , ordered=False)

# %%
(jb
 .rename(columns=lambda c: c.replace('.', '_'))
 #.where(jb['is_python_main'] == 'Yes', other='False')
 .is_python_main
 .value_counts(dropna=False))
# Out:
# Yes                                               33528
# NaN                                               12730
# No, I use Python as a secondary language           5992
# No, I don’t use Python for my current projects     2212
# Name: is_python_main, dtype: int64

# %%
jb2

missing = jb2.is_python_main.isna()

jb2.memory_usage(deep=True)
# Out:
# Index                           128
# is_python_main              3385152
# other_lang_None             1928442
# other_lang_Java             1977945
# other_lang_JavaScript       2325954
#                              ...
# job_role_CIO / CEO / CTO    1795584
# job_role_Systems analyst    1797304
# job_role_Other              1820634
# age                         3214332
# country_live                2576032
# Length: 265, dtype: int64
